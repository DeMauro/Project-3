# %% [markdown]
# ### Explore & Clean Data

# %%
import pandas as pd

path= "loan_data.json"
df= pd.read_json(path)
df
# Out:
#     Application_ID  Gender Married Dependents     Education Self_Employed  \
# 0         LP001002    Male      No          0      Graduate            No
# 1         LP001003    Male     Yes          1      Graduate            No
# 2         LP001005    Male     Yes          0      Graduate           Yes
# 3         LP001006    Male     Yes          0  Not Graduate            No
# 4         LP001008    Male      No          0      Graduate            No
# ..             ...     ...     ...        ...           ...           ...
# 506       LP002978  Female      No          0      Graduate            No
# 507       LP002979    Male     Yes         3+      Graduate            No
# 508       LP002983    Male     Yes          1      Graduate            No
# 509       LP002984    Male     Yes          2      Graduate            No
# 510       LP002990  Female      No          0      Graduate           Yes
#
#      Credit_History Property_Area  Income Application_Status
# 0                 1         Urban  medium                  Y
# 1                 1         Rural  medium                  N
# 2                 1         Urban     low                  Y
# 3                 1         Urban     low                  Y
# 4                 1         Urban  medium                  Y
# ..              ...           ...     ...                ...
# 506               1         Rural     low                  Y
# 507               1         Rural  medium                  Y
# 508               1         Urban  medium                  Y
# 509               1         Urban  medium                  Y
# 510               0     Semiurban  medium                  N
#
# [511 rows x 10 columns]

# %%
# Remove nulls
clean_df= df.dropna()
clean_df
# Out:
#     Application_ID  Gender Married Dependents     Education Self_Employed  \
# 0         LP001002    Male      No          0      Graduate            No
# 1         LP001003    Male     Yes          1      Graduate            No
# 2         LP001005    Male     Yes          0      Graduate           Yes
# 3         LP001006    Male     Yes          0  Not Graduate            No
# 4         LP001008    Male      No          0      Graduate            No
# ..             ...     ...     ...        ...           ...           ...
# 506       LP002978  Female      No          0      Graduate            No
# 507       LP002979    Male     Yes         3+      Graduate            No
# 508       LP002983    Male     Yes          1      Graduate            No
# 509       LP002984    Male     Yes          2      Graduate            No
# 510       LP002990  Female      No          0      Graduate           Yes
#
#      Credit_History Property_Area  Income Application_Status
# 0                 1         Urban  medium                  Y
# 1                 1         Rural  medium                  N
# 2                 1         Urban     low                  Y
# 3                 1         Urban     low                  Y
# 4                 1         Urban  medium                  Y
# ..              ...           ...     ...                ...
# 506               1         Rural     low                  Y
# 507               1         Rural  medium                  Y
# 508               1         Urban  medium                  Y
# 509               1         Urban  medium                  Y
# 510               0     Semiurban  medium                  N
#
# [511 rows x 10 columns]

# %% [markdown]
# ### Transform Data

# %%
# Change Male, Married, Graduate, Self_Employeed & Approved Application Status= 1 
one_df=clean_df.replace(["Male", "Yes", "Graduate", "Y"],1)

# Change Female, NOT Married, NOT Graduate, NOT Self_Employeed & Decline Application Status= 0 
zero_df=one_df.replace(["Female","No", "Not Graduate", "N"],0)

# Let us view what we got
zero_df
# Out:
#     Application_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0         LP001002       1        0          0          1              0
# 1         LP001003       1        1          1          1              0
# 2         LP001005       1        1          0          1              1
# 3         LP001006       1        1          0          0              0
# 4         LP001008       1        0          0          1              0
# ..             ...     ...      ...        ...        ...            ...
# 506       LP002978       0        0          0          1              0
# 507       LP002979       1        1         3+          1              0
# 508       LP002983       1        1          1          1              0
# 509       LP002984       1        1          2          1              0
# 510       LP002990       0        0          0          1              1
#
#      Credit_History Property_Area  Income  Application_Status
# 0                 1         Urban  medium                   1
# 1                 1         Rural  medium                   0
# 2                 1         Urban     low                   1
# 3                 1         Urban     low                   1
# 4                 1         Urban  medium                   1
# ..              ...           ...     ...                 ...
# 506               1         Rural     low                   1
# 507               1         Rural  medium                   1
# 508               1         Urban  medium                   1
# 509               1         Urban  medium                   1
# 510               0     Semiurban  medium                   0
#
# [511 rows x 10 columns]

# %%
# Explore the Property Area Column 
zero_df["Property_Area"].value_counts()
# Out:
# Semiurban    197
# Urban        165
# Rural        149
# Name: Property_Area, dtype: int64

# %%
# Explore the Income Column 
zero_df["Income"].value_counts()
# Out:
# low       273
# medium    193
# high       45
# Name: Income, dtype: int64

# %%
# Convert Property Area Column
# Semiurban, low= 0
semi_df=zero_df.replace(["Semiurban", "low"],0)

# Urban, medium= 1
urban_df=semi_df.replace(["Urban", "medium"],1)

# Rural, high= 2
rural_df=urban_df.replace(["Rural", "high"],2)

rural_df
# Out:
#     Application_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0         LP001002       1        0          0          1              0
# 1         LP001003       1        1          1          1              0
# 2         LP001005       1        1          0          1              1
# 3         LP001006       1        1          0          0              0
# 4         LP001008       1        0          0          1              0
# ..             ...     ...      ...        ...        ...            ...
# 506       LP002978       0        0          0          1              0
# 507       LP002979       1        1         3+          1              0
# 508       LP002983       1        1          1          1              0
# 509       LP002984       1        1          2          1              0
# 510       LP002990       0        0          0          1              1
#
#      Credit_History  Property_Area  Income  Application_Status
# 0                 1              1       1                   1
# 1                 1              2       1                   0
# 2                 1              1       0                   1
# 3                 1              1       0                   1
# 4                 1              1       1                   1
# ..              ...            ...     ...                 ...
# 506               1              2       0                   1
# 507               1              2       1                   1
# 508               1              1       1                   1
# 509               1              1       1                   1
# 510               0              0       1                   0
#
# [511 rows x 10 columns]

# %%
# Fixing Dependents of 3+ to 3
final_df=rural_df.replace("3+",3)
final_df
# Out:
#     Application_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0         LP001002       1        0          0          1              0
# 1         LP001003       1        1          1          1              0
# 2         LP001005       1        1          0          1              1
# 3         LP001006       1        1          0          0              0
# 4         LP001008       1        0          0          1              0
# ..             ...     ...      ...        ...        ...            ...
# 506       LP002978       0        0          0          1              0
# 507       LP002979       1        1          3          1              0
# 508       LP002983       1        1          1          1              0
# 509       LP002984       1        1          2          1              0
# 510       LP002990       0        0          0          1              1
#
#      Credit_History  Property_Area  Income  Application_Status
# 0                 1              1       1                   1
# 1                 1              2       1                   0
# 2                 1              1       0                   1
# 3                 1              1       0                   1
# 4                 1              1       1                   1
# ..              ...            ...     ...                 ...
# 506               1              2       0                   1
# 507               1              2       1                   1
# 508               1              1       1                   1
# 509               1              1       1                   1
# 510               0              0       1                   0
#
# [511 rows x 10 columns]

# %%
# not sure what credit history lebling means.
# I am assuming 1=yes and 2=no
df["Credit_History"].value_counts()
# Out:
# 1    431
# 0     80
# Name: Credit_History, dtype: int64

# %% [markdown]
# ### Create Variables

# %%
# Create Variables
X=final_df.drop(["Application_ID","Application_Status"], axis=1)
y=final_df["Application_Status"]

print(X.shape, y.shape)
# Out:
# (511, 8) (511,)

# %% [markdown]
# ### Test - Train - Split

# %%
#Test, Train, Split Data 
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
# Create a decision Tree
from sklearn import tree

# Create a Model
model=tree.DecisionTreeClassifier()

#Fit the model
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
# checking the quality score
model.score(X_test, y_test)
# Out:
# 0.734375

# %%
model.predict([[0,1,1,0,1,0,1,0]])
# Out:
# array([0], dtype=int64)

# %%
# pip install graphviz

# %%
from sklearn.datasets import load_iris
import graphviz

dot_data=tree.export_graphviz(model, out_file=None)
graph=graphviz.Source(dot_data)

# %%
tree.plot_tree(model)
# Out:
# [Text(122.92271784232364, 355.38461538461536, 'X[5] <= 0.5\ngini = 0.443\nsamples = 383\nvalue = [127, 256]'),
#  Text(26.7551867219917, 326.95384615384614, 'X[7] <= 0.5\ngini = 0.153\nsamples = 60\nvalue = [55, 5]'),
#  Text(12.348547717842322, 298.5230769230769, 'X[0] <= 0.5\ngini = 0.061\nsamples = 32\nvalue = [31, 1]'),
#  Text(8.232365145228215, 270.09230769230766, 'X[3] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(4.1161825726141075, 241.66153846153844, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(12.348547717842322, 241.66153846153844, 'X[6] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(8.232365145228215, 213.2307692307692, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(16.46473029045643, 213.2307692307692, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(16.46473029045643, 270.09230769230766, 'gini = 0.0\nsamples = 26\nvalue = [26, 0]'),
#  Text(41.161825726141075, 298.5230769230769, 'X[4] <= 0.5\ngini = 0.245\nsamples = 28\nvalue = [24, 4]'),
#  Text(37.04564315352697, 270.09230769230766, 'X[2] <= 0.5\ngini = 0.32\nsamples = 20\nvalue = [16, 4]'),
#  Text(28.813278008298752, 241.66153846153844, 'X[6] <= 1.0\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(24.697095435684645, 213.2307692307692, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(32.92946058091286, 213.2307692307692, 'X[3] <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(28.813278008298752, 184.79999999999998, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(37.04564315352697, 184.79999999999998, 'gini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(45.27800829875518, 241.66153846153844, 'X[1] <= 0.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(41.161825726141075, 213.2307692307692, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(49.39419087136929, 213.2307692307692, 'X[3] <= 0.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(45.27800829875518, 184.79999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(53.5103734439834, 184.79999999999998, 'X[2] <= 2.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(49.39419087136929, 156.36923076923074, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(57.626556016597505, 156.36923076923074, 'X[7] <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(53.5103734439834, 127.93846153846152, 'X[6] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(49.39419087136929, 99.50769230769231, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(57.626556016597505, 99.50769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(61.74273858921161, 127.93846153846152, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(45.27800829875518, 270.09230769230766, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(219.09024896265558, 326.95384615384614, 'X[6] <= 0.5\ngini = 0.346\nsamples = 323\nvalue = [72, 251]'),
#  Text(126.31535269709542, 298.5230769230769, 'X[7] <= 0.5\ngini = 0.242\nsamples = 121\nvalue = [17, 104]'),
#  Text(100.84647302904563, 270.09230769230766, 'X[1] <= 0.5\ngini = 0.121\nsamples = 62\nvalue = [4, 58]'),
#  Text(90.55601659751036, 241.66153846153844, 'X[4] <= 0.5\ngini = 0.245\nsamples = 21\nvalue = [3, 18]'),
#  Text(86.43983402489626, 213.2307692307692, 'X[2] <= 0.5\ngini = 0.18\nsamples = 20\nvalue = [2, 18]'),
#  Text(78.20746887966804, 184.79999999999998, 'X[3] <= 0.5\ngini = 0.111\nsamples = 17\nvalue = [1, 16]'),
#  Text(74.09128630705393, 156.36923076923074, 'X[0] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(69.97510373443983, 127.93846153846152, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(78.20746887966804, 127.93846153846152, 'gini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(82.32365145228215, 156.36923076923074, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(94.67219917012447, 184.79999999999998, 'X[0] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(90.55601659751036, 156.36923076923074, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text