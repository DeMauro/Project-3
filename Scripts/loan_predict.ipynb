# %% [markdown]
# ### Load & Join Data

# %%
# Loading in data

import pandas as pd
import numpy as np
import pandas as pd

import warnings
warnings.simplefilter('ignore', FutureWarning)

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical



info1=pd.read_csv("../Resources/loan_table.csv")

info1
# Out:
#         loan_id     loan_purpose        date  loan_granted  loan_repaid
# 0         19454       investment  2012-03-15             0          NaN
# 1        496811       investment  2012-01-17             0          NaN
# 2        929493            other  2012-02-09             0          NaN
# 3        580653            other  2012-06-27             1          1.0
# 4        172419         business  2012-05-21             1          0.0
# ...         ...              ...         ...           ...          ...
# 101095   734902  emergency_funds  2012-01-30             1          0.0
# 101096   712467         business  2012-11-22             1          0.0
# 101097   209268            other  2012-09-13             1          1.0
# 101098   779254         business  2012-02-08             1          1.0
# 101099   774414            other  2012-05-09             0          NaN
#
# [101100 rows x 5 columns]

# %%
info2=pd.read_csv("../Resources/borrower_table.csv")

info2
# Out:
#         loan_id  is_first_loan  fully_repaid_previous_loans  \
# 0        289774              1                          NaN
# 1        482590              0                          1.0
# 2        135565              1                          NaN
# 3        207797              0                          1.0
# 4        828078              0                          0.0
# ...         ...            ...                          ...
# 101095    38238              1                          NaN
# 101096   590712              1                          NaN
# 101097   961276              1                          NaN
# 101098   551027              0                          1.0
# 101099   761999              1                          NaN
#
#         currently_repaying_other_loans  total_credit_card_limit  \
# 0                                  NaN                     8000
# 1                                  0.0                     4500
# 2                                  NaN                     6900
# 3                                  0.0                     1200
# 4                                  0.0                     6900
# ...                                ...                      ...
# 101095                             NaN                     2200
# 101096                             NaN                     3800
# 101097                             NaN                     1600
# 101098                             0.0                     7000
# 101099                             NaN                     2300
#
#         avg_percentage_credit_card_limit_used_last_year  saving_amount  \
# 0                                                  0.49           3285
# 1                                                  1.03            636
# 2                                                  0.82           2085
# 3                                                  0.82            358
# 4                                                  0.80           2138
# ...                                                 ...            ...
# 101095                                             0.83           1295
# 101096                                             0.70            340
# 101097                                             1.06            445
# 101098                                             0.82            354
# 101099                                             0.47           2999
#
#         checking_amount  is_employed  yearly_salary  age  dependent_number
# 0                  1073            0              0   47                 3
# 1                  5299            1          13500   33                 1
# 2                  3422            1          24500   38                 8
# 3                  3388            0              0   24                 1
# 4                  4282            1          18100   36                 1
# ...                 ...          ...            ...  ...               ...
# 101095             2240            0              0   47                 2
# 101096             3802            1          36100   41                 7
# 101097             1757            1          40800   71                 3
# 101098             1435            1          41900   44                 2
# 101099             4420            1          44200   36                 7
#
# [101100 rows x 12 columns]

# %%
new_df=info1.set_index("loan_id").join(info2.set_index("loan_id"))
join_df=new_df.drop("date", axis=1)
join_df
# Out:
#             loan_purpose  loan_granted  loan_repaid  is_first_loan  \
# loan_id
# 19454         investment             0          NaN              1
# 496811        investment             0          NaN              1
# 929493             other             0          NaN              1
# 580653             other             1          1.0              0
# 172419          business             1          0.0              1
# ...                  ...           ...          ...            ...
# 734902   emergency_funds             1          0.0              0
# 712467          business             1          0.0              1
# 209268             other             1          1.0              1
# 779254          business             1          1.0              0
# 774414             other             0          NaN              1
#
#          fully_repaid_previous_loans  currently_repaying_other_loans  \
# loan_id
# 19454                            NaN                             NaN
# 496811                           NaN                             NaN
# 929493                           NaN                             NaN
# 580653                           1.0                             0.0
# 172419                           NaN                             NaN
# ...                              ...                             ...
# 734902                           1.0                             0.0
# 712467                           NaN                             NaN
# 209268                           NaN                             NaN
# 779254                           1.0                             0.0
# 774414                           NaN                             NaN
#
#          total_credit_card_limit  \
# loan_id
# 19454                       8600
# 496811                      5300
# 929493                         0
# 580653                      5400
# 172419                      2900
# ...                          ...
# 734902                      2400
# 712467                      3100
# 209268                      4600
# 779254                      6500
# 774414                      3100
#
#          avg_percentage_credit_card_limit_used_last_year  saving_amount  \
# loan_id
# 19454                                               0.79           1491
# 496811                                              0.52            141
# 929493                                               NaN            660
# 580653                                              0.52           3345
# 172419                                              0.76           1050
# ...                                                  ...            ...
# 734902                                              0.40            553
# 712467                                              0.68            367
# 209268                                              0.50           1134
# 779254                                              0.70            661
# 774414                                              0.58           1449
#
#          checking_amount  is_employed  yearly_salary  age  dependent_number
# loan_id
# 19454               6285            1          45200   42                 7
# 496811              5793            0              0   42                 5
# 929493              3232            1          26500   60                 4
# 580653              2764            1          15800   58                 4
# 172419              3695            1          34800   31                 4
# ...                  ...          ...            ...  ...               ...
# 734902              2372            1          37000   56                 3
# 712467              1957            1          22700   59                 5
# 209268              1621            1          35200   49                 1
# 779254              4333            1          19600   51                 4
# 774414              2404            0              0   62                 1
#
# [101100 rows x 14 columns]

# %% [markdown]
# ### Explore Data

# %%
# Checking column values, inorder to evaluate what Null's should be
join_df["loan_repaid"].value_counts()
# Out:
# 1.0    30706
# 0.0    16948
# Name: loan_repaid, dtype: int64

# %%
# Checking column values, inorder to evaluate what Null's should be
join_df["fully_repaid_previous_loans"].value_counts()
# Out:
# 1.0    41505
# 0.0     4648
# Name: fully_repaid_previous_loans, dtype: int64

# %%
# Checking column values, inorder to evaluate what Null's should be
join_df["currently_repaying_other_loans"].value_counts()
# Out:
# 0.0    29338
# 1.0    16815
# Name: currently_repaying_other_loans, dtype: int64

# %%
# Most likely will convert the NA's to 
join_df["avg_percentage_credit_card_limit_used_last_year"].max()
# Out:
# 1.09

# %% [markdown]
# ### Trasform Data

# %%
join_df[['loan_repaid','fully_repaid_previous_loans','currently_repaying_other_loans']] = join_df[['loan_repaid','fully_repaid_previous_loans','currently_repaying_other_loans']].fillna(2)
join_df
# Out:
#             loan_purpose  loan_granted  loan_repaid  is_first_loan  \
# loan_id
# 19454         investment             0          2.0              1
# 496811        investment             0          2.0              1
# 929493             other             0          2.0              1
# 580653             other             1          1.0              0
# 172419          business             1          0.0              1
# ...                  ...           ...          ...            ...
# 734902   emergency_funds             1          0.0              0
# 712467          business             1          0.0              1
# 209268             other             1          1.0              1
# 779254          business             1          1.0              0
# 774414             other             0          2.0              1
#
#          fully_repaid_previous_loans  currently_repaying_other_loans  \
# loan_id
# 19454                            2.0                             2.0
# 496811                           2.0                             2.0
# 929493                           2.0                             2.0
# 580653                           1.0                             0.0
# 172419                           2.0                             2.0
# ...                              ...                             ...
# 734902                           1.0                             0.0
# 712467                           2.0                             2.0
# 209268                           2.0                             2.0
# 779254                           1.0                             0.0
# 774414                           2.0                             2.0
#
#          total_credit_card_limit  \
# loan_id
# 19454                       8600
# 496811                      5300
# 929493                         0
# 580653                      5400
# 172419                      2900
# ...                          ...
# 734902                      2400
# 712467                      3100
# 209268                      4600
# 779254                      6500
# 774414                      3100
#
#          avg_percentage_credit_card_limit_used_last_year  saving_amount  \
# loan_id
# 19454                                               0.79           1491
# 496811                                              0.52            141
# 929493                                               NaN            660
# 580653                                              0.52           3345
# 172419                                              0.76           1050
# ...                                                  ...            ...
# 734902                                              0.40            553
# 712467                                              0.68            367
# 209268                                              0.50           1134
# 779254                                              0.70            661
# 774414                                              0.58           1449
#
#          checking_amount  is_employed  yearly_salary  age  dependent_number
# loan_id
# 19454               6285            1          45200   42                 7
# 496811              5793            0              0   42                 5
# 929493              3232            1          26500   60                 4
# 580653              2764            1          15800   58                 4
# 172419              3695            1          34800   31                 4
# ...                  ...          ...            ...  ...               ...
# 734902              2372            1          37000   56                 3
# 712467              1957            1          22700   59                 5
# 209268              1621            1          35200   49                 1
# 779254              4333            1          19600   51                 4
# 774414              2404            0              0   62                 1
#
# [101100 rows x 14 columns]

# %%
join_df['avg_percentage_credit_card_limit_used_last_year'] = join_df['avg_percentage_credit_card_limit_used_last_year'].fillna(0)
join_df
# Out:
#             loan_purpose  loan_granted  loan_repaid  is_first_loan  \
# loan_id
# 19454         investment             0          2.0              1
# 496811        investment             0          2.0              1
# 929493             other             0          2.0              1
# 580653             other             1          1.0              0
# 172419          business             1          0.0              1
# ...                  ...           ...          ...            ...
# 734902   emergency_funds             1          0.0              0
# 712467          business             1          0.0              1
# 209268             other             1          1.0              1
# 779254          business             1          1.0              0
# 774414             other             0          2.0              1
#
#          fully_repaid_previous_loans  currently_repaying_other_loans  \
# loan_id
# 19454                            2.0                             2.0
# 496811                           2.0                             2.0
# 929493                           2.0                             2.0
# 580653                           1.0                             0.0
# 172419                           2.0                             2.0
# ...                              ...                             ...
# 734902                           1.0                             0.0
# 712467                           2.0                             2.0
# 209268                           2.0                             2.0
# 779254                           1.0                             0.0
# 774414                           2.0                             2.0
#
#          total_credit_card_limit  \
# loan_id
# 19454                       8600
# 496811                      5300
# 929493                         0
# 580653                      5400
# 172419                      2900
# ...                          ...
# 734902                      2400
# 712467                      3100
# 209268                      4600
# 779254                      6500
# 774414                      3100
#
#          avg_percentage_credit_card_limit_used_last_year  saving_amount  \
# loan_id
# 19454                                               0.79           1491
# 496811                                              0.52            141
# 929493                                              0.00            660
# 580653                                              0.52           3345
# 172419                                              0.76           1050
# ...                                                  ...            ...
# 734902                                              0.40            553
# 712467                                              0.68            367
# 209268                                              0.50           1134
# 779254                                              0.70            661
# 774414                                              0.58           1449
#
#          checking_amount  is_employed  yearly_salary  age  dependent_number
# loan_id
# 19454               6285            1          45200   42                 7
# 496811              5793            0              0   42                 5
# 929493              3232            1          26500   60                 4
# 580653              2764            1          15800   58                 4
# 172419              3695            1          34800   31                 4
# ...                  ...          ...            ...  ...               ...
# 734902              2372            1          37000   56                 3
# 712467              1957            1          22700   59                 5
# 209268              1621            1          35200   49                 1
# 779254              4333            1          19600   51                 4
# 774414              2404            0              0   62                 1
#
# [101100 rows x 14 columns]

# %%
join_df["loan_purpose"].value_counts()
# Out:
# home               24314
# business           21707
# investment         21484
# emergency_funds    18091
# other              15504
# Name: loan_purpose, dtype: int64

# %%
home_df=join_df.replace("home",0)
business_df=home_df.replace("business",1)
investment_df=business_df.replace("investment",2)
ef_df=investment_df.replace("emergency_funds",3)
final_df=ef_df.replace("other",4)

# %%
final_df
# Out:
#          loan_purpose  loan_granted  loan_repaid  is_first_loan  \
# loan_id
# 19454               2             0          2.0              1
# 496811              2             0          2.0              1
# 929493              4             0          2.0              1
# 580653              4             1          1.0              0
# 172419              1             1          0.0              1
# ...               ...           ...          ...            ...
# 734902              3             1          0.0              0
# 712467              1             1          0.0              1
# 209268              4             1          1.0              1
# 779254              1             1          1.0              0
# 774414              4             0          2.0              1
#
#          fully_repaid_previous_loans  currently_repaying_other_loans  \
# loan_id
# 19454                            2.0                             2.0
# 496811                           2.0                             2.0
# 929493                           2.0                             2.0
# 580653                           1.0                             0.0
# 172419                           2.0                             2.0
# ...                              ...                             ...
# 734902                           1.0                             0.0
# 712467                           2.0                             2.0
# 209268                           2.0                             2.0
# 779254                           1.0                             0.0
# 774414                           2.0                             2.0
#
#          total_credit_card_limit  \
# loan_id
# 19454                       8600
# 496811                      5300
# 929493                         0
# 580653                      5400
# 172419                      2900
# ...                          ...
# 734902                      2400
# 712467                      3100
# 209268                      4600
# 779254                      6500
# 774414                      3100
#
#          avg_percentage_credit_card_limit_used_last_year  saving_amount  \
# loan_id
# 19454                                               0.79           1491
# 496811                                              0.52            141
# 929493                                              0.00            660
# 580653                                              0.52           3345
# 172419                                              0.76           1050
# ...                                                  ...            ...
# 734902                                              0.40            553
# 712467                                              0.68            367
# 209268                                              0.50           1134
# 779254                                              0.70            661
# 774414                                              0.58           1449
#
#          checking_amount  is_employed  yearly_salary  age  dependent_number
# loan_id
# 19454               6285            1          45200   42                 7
# 496811              5793            0              0   42                 5
# 929493              3232            1          26500   60                 4
# 580653              2764            1          15800   58                 4
# 172419              3695            1          34800   31                 4
# ...                  ...          ...            ...  ...               ...
# 734902              2372            1          37000   56                 3
# 712467              1957            1          22700   59                 5
# 209268              1621            1          35200   49                 1
# 779254              4333            1          19600   51                 4
# 774414              2404            0              0   62                 1
#
# [101100 rows x 14 columns]

# %% [markdown]
# ### Test-Train-Split

# %%
X=final_df.drop("loan_granted", axis=1)
y=final_df["loan_granted"]

print(X.shape, y.shape)
# Out:
# (101100, 13) (101100,)

# %%
#Test, Train, Split Data 
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y)

# %% [markdown]
# ### Decision Tree

# %%
# Create a decision Tree
from sklearn import tree

# Create a Model
model=tree.DecisionTreeClassifier()

#Fit the model
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
# checking the quality score
model.score(X_test, y_test)
# Out:
# 1.0

# %%
final_df.head()
# Out:
#          loan_purpose  loan_granted  loan_repaid  is_first_loan  \
# loan_id
# 19454               2             0          2.0              1
# 496811              2             0          2.0              1
# 929493              4             0          2.0              1
# 580653              4             1          1.0              0
# 172419              1             1          0.0              1
#
#          fully_repaid_previous_loans  currently_repaying_other_loans  \
# loan_id
# 19454                            2.0                             2.0
# 496811                           2.0                             2.0
# 929493                           2.0                             2.0
# 580653                           1.0                             0.0
# 172419                           2.0                             2.0
#
#          total_credit_card_limit  \
# loan_id
# 19454                       8600
# 496811                      5300
# 929493                         0
# 580653                      5400
# 172419                      2900
#
#          avg_percentage_credit_card_limit_used_last_year  saving_amount  \
# loan_id
# 19454                                               0.79           1491
# 496811                                              0.52            141
# 929493                                              0.00            660
# 580653                                              0.52           3345
# 172419                                              0.76           1050
#
#          checking_amount  is_employed  yearly_salary  age  dependent_number
# loan_id
# 19454               6285            1          45200   42                 7
# 496811              5793            0              0   42                 5
# 929493              3232            1          26500   60                 4
# 580653              2764            1          15800   58                 4
# 172419              3695            1          34800   31                 4

# %%
model.predict([[0,1,0,1,0,5300,0.5,100,5000,1,25000,35,3]])
# Out:
# array([1], dtype=int64)

# %%
#Save the model
model.save("../Resources/loan_model.h5")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-7f62b0f96f10> in <module>
#       1 #Save the model
#       2 from tensorflow.keras.models import load_model
# ----> 3 model.save("../Resources/loan_model.h5")
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'save'
